# %%
# !wget https://github.com/maciejszewczyk/yolo11-obb-car-parking-lot/raw/6193851a1ea9a2ac4498f94ff7fe712686b6ab3a/yolo11_obb_car_parking_lot.zip
# Out:
# --2025-08-01 17:45:16--  https://github.com/maciejszewczyk/yolo11-obb-car-parking-lot/raw/6193851a1ea9a2ac4498f94ff7fe712686b6ab3a/yolo11_obb_car_parking_lot.zip
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/maciejszewczyk/yolo11-obb-car-parking-lot/6193851a1ea9a2ac4498f94ff7fe712686b6ab3a/yolo11_obb_car_parking_lot.zip [following]
# --2025-08-01 17:45:17--  https://raw.githubusercontent.com/maciejszewczyk/yolo11-obb-car-parking-lot/6193851a1ea9a2ac4498f94ff7fe712686b6ab3a/yolo11_obb_car_parking_lot.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !unzip "yolo11_obb_car_parking_lot.zip"
# Out:
# Archive:  yolo11_obb_car_parking_lot.zip
#    creating: dataset/
#    creating: dataset/test/
#    creating: dataset/test/images/
#   inflating: dataset/test/images/video2-11-_png.rf.d1502e2a324670d2a6b86c2c6652ef2c.jpg
#   inflating: dataset/test/images/video2-4-_png.rf.b9013fd5b688c7d3e08a4c232c6b31ba.jpg
#   inflating: dataset/test/images/video3-2-_png.rf.1ad7bf45b7b03650411328fc3eed2ef0.jpg
#   inflating: dataset/test/images/video3-4-_png.rf.869031d7e4d9af4cd51c3e1d4119e599.jpg
#   inflating: dataset/test/images/video4-1-_png.rf.9e727de75976cfa6b596981af4c7b4e8.jpg
#   inflating: dataset/test/images/video4-8-_png.rf.040785092a4795d2da6c3841f1a7a892.jpg
#   inflating: dataset/test/images/vlcsnap-2024-12-27-14h26m52s383_png.rf.8b4789a644b9562e9ff5ff30580ae41a.jpg
#    creating: dataset/test/labels/
#   inflating: dataset/test/labels/video2-11-_png.rf.d1502e2a324670d2a6b86c2c6652ef2c.txt
#   inflating: dataset/test/labels/video2-4-_png.rf.b9013fd5b688c7d3e08a4c232c6b31ba.txt
# ...

# %%
# !wget https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11l-obb.pt
# Out:
# --2025-08-01 17:45:48--  https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11l-obb.pt
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.172 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.9/112.6 GB disk)

# %%
# !yolo obb train model=yolo11l-obb.pt data=data.yaml workers=0 batch=2 device=0 imgsz=640 epochs=100 patience=50 name=yolo11_obb amp=false
# Out:
# Ultralytics 8.3.172 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# %ls runs/obb/yolo11_obb/weights/best.pt
# Out:
# runs/obb/yolo11_obb/weights/best.pt
